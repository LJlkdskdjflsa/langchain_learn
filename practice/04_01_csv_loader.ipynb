# %%
from langchain.document_loaders.csv_loader import CSVLoader

# %%
loader = CSVLoader(file_path='./records_202312021539.csv')
data = loader.load()

# %%
print(data)
# Out:
# [Document(page_content='start_time: 2023-12-02 07:00:00.572\nend_time: 2023-12-02 07:28:00.572\ntitle: Better Self 訪問丹尼爾', metadata={'source': './records_202312021539.csv', 'row': 0}), Document(page_content='start_time: 2023-12-02 06:44:00.591\nend_time: 2023-12-02 07:00:00.591\ntitle: 看影片', metadata={'source': './records_202312021539.csv', 'row': 1}), Document(page_content='start_time: 2023-12-02 06:00:00.667\nend_time: 2023-12-02 06:44:00.667\ntitle: 看影片', metadata={'source': './records_202312021539.csv', 'row': 2}), Document(page_content='start_time: 2023-12-02 05:30:00.320\nend_time: 2023-12-02 06:00:00.320\ntitle: 坐車回家', metadata={'source': './records_202312021539.csv', 'row': 3}), Document(page_content='start_time: 2023-12-02 03:45:00.534\nend_time: 2023-12-02 05:30:00.534\ntitle: 吃飯', metadata={'source': './records_202312021539.csv', 'row': 4}), Document(page_content='start_time: 2023-12-02 03:15:00.061\nend_time: 2023-12-02 03:45:00.061\ntitle: 騎車', metadata={'source': './rec
# ...

# %%
len(data)
# Out:
# 200

# %%
data[0].page_content
# Out:
# 'start_time: 2023-12-02 07:00:00.572\nend_time: 2023-12-02 07:28:00.572\ntitle: Better Self 訪問丹尼爾'
